# %% [markdown]
# # Dimension Reduction

# %% [markdown]
# ## Data Collection

# %% [markdown]
# Data:
#    The university details are obtained from the US Higher Education Body and is publicly available for students to access.
#
# Data Dictionary:
# - Dataset contains 25 university details
# - 7 features are recorded for each university
#
# Description:
# - Univ - University Name
# - State - Location (state) of the university
# - SAT - Average SAT score for eligibility
# - Top10 - % of students who ranked in top 10 in their previous academics
# - Accept - % of students admitted to the universities
# - SFRatio - Student to Faculty ratio
# - Expenses - Overall cost in USD
# - GradRate - % of students who graduate

# %% [markdown]
# #### Install the required packages if not available

# %%
# !pip install feature_engine
# !pip install dtale

# %% [markdown]
# **Importing required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.decomposition import PCA
from kneed import KneeLocator

# %% [markdown]
# ### Suppress the Warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Import the data**

# %%
df = pd.read_excel(r"C:\Users\Swapnil Mishra\Desktop\DS_Codes_Swapnil\PCA\University_Clustering\University_Clustering.xlsx")
df
# Out:
#     UnivID          Univ State     SAT  Top10  Accept  SFRatio  Expenses  \
# 0        1         Brown    RI  1310.0     89      22     13.0     22704
# 1        2       CalTech    CA  1415.0    100      25      6.0     63575
# 2        3           CMU    PA  1260.0     62      59      9.0     25026
# 3        4      Columbia    NY  1310.0     76      24     12.0     31510
# 4        5       Cornell    NY  1280.0     83      33     13.0     21864
# 5        6     Dartmouth    NH  1340.0     89      23     10.0     32162
# 6        7          Duke    NC  1315.0     90      30     12.0     31585
# 7        8    Georgetown    DC     NaN     74      24     12.0     20126
# 8        9       Harvard    MA  1400.0     91      14     11.0     39525
# 9       10  JohnsHopkins    MD  1305.0     75      44      7.0     58691
# 10      11           MIT    MA  1380.0     94      30     10.0     34870
# 11      12  Northwestern    IL  1260.0     85      39     11.0     28052
# 12      13     NotreDame    IN  1255.0     81      42     13.0     15122
# 13      14     PennState    PA  1081.0     38      54     18.0     10185
# 14      15     Princeton    NJ  1375.0     91      14      8.0     30220
# 15      16        Purdue    IN  1005.0     28      90     19.0      9066
# 16      17      Stanford    CA  1360.0     90      20     12.0     36450
# 17      18      TexasA&M    TX  1075.0     49      67     25.0      8704
# 18      19    UCBerkeley    CA  1240.0     95      40     17.0     15140
# 19      20      UChicago    IL  1290.0     75      50      NaN     38380
# 20      21     UMichigan    MI  1180.0     65      68     16.0     15470
# 21      22         UPenn    PA  1285.0     80      36     11.0     27553
# 22      23           UVA    VA  1225.0     77      44     14.0     13349
# 23      24    UWisconsin    WI  1085.0     40      69     15.0     11857
# 24      25          Yale    CT  1375.0     95      19     11.0     43514
#
#     GradRate
# 0       94.0
# 1       81.0
# 2       72.0
# 3        NaN
# 4       90.0
# 5       95.0
# 6       95.0
# 7       92.0
# 8       97.0
# 9       87.0
# 10      91.0
# 11      89.0
# 12      94.0
# 13      80.0
# 14      95.0
# 15      69.0
# 16      93.0
# 17      67.0
# 18      78.0
# 19      87.0
# 20      85.0
# 21      90.0
# 22      92.0
# 23      71.0
# 24      96.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   UnivID    25 non-null     int64
#  1   Univ      25 non-null     object
#  2   State     25 non-null     object
#  3   SAT       24 non-null     float64
#  4   Top10     25 non-null     int64
#  5   Accept    25 non-null     int64
#  6   SFRatio   24 non-null     float64
#  7   Expenses  25 non-null     int64
#  8   GradRate  24 non-null     float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.9+ KB

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA) / DESCRIPTIVE STATISTICS

# %% [markdown]
# ***Descriptive Statistics and Data Distribution Function***

# %%
df.describe()
# Out:
#           UnivID          SAT       Top10     Accept    SFRatio      Expenses  \
# count  25.000000    24.000000   25.000000  25.000000  24.000000     25.000000
# mean   13.000000  1266.916667   76.480000  39.200000  12.708333  27388.000000
# std     7.359801   110.663578   19.433905  19.727308   4.154402  14424.883165
# min     1.000000  1005.000000   28.000000  14.000000   6.000000   8704.000000
# 25%     7.000000  1236.250000   74.000000  24.000000  10.750000  15140.000000
# 50%    13.000000  1287.500000   81.000000  36.000000  12.000000  27553.000000
# 75%    19.000000  1345.000000   90.000000  50.000000  14.250000  34870.000000
# max    25.000000  1415.000000  100.000000  90.000000  25.000000  63575.000000
#
#         GradRate
# count  24.000000
# mean   86.666667
# std     9.248580
# min    67.000000
# 25%    80.750000
# 50%    90.000000
# 75%    94.000000
# max    97.000000

# %% [markdown]
# # Data Preprocessing

# %%
# Drop the unwanted features
df1 = df.drop(["UnivID"], axis = 1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   State     25 non-null     object
#  2   SAT       24 non-null     float64
#  3   Top10     25 non-null     int64
#  4   Accept    25 non-null     int64
#  5   SFRatio   24 non-null     float64
#  6   Expenses  25 non-null     int64
#  7   GradRate  24 non-null     float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.7+ KB

# %% [markdown]
# ## Checking Null Values

# %%
df1.isnull().sum()
# Out:
# Univ        0
# State       0
# SAT         1
# Top10       0
# Accept      0
# SFRatio     1
# Expenses    0
# GradRate    1
# dtype: int64

# %% [markdown]
# ### PCA can be implemented only on Numeric features

# %%
numeric_features = df1.select_dtypes(exclude = ['object']).columns

# %%
numeric_features
# Out:
# Index(['SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate'], dtype='object')

# %% [markdown]
# ## Define the Pipeline steps

# %% [markdown]
# #### Define PCA model

# %%
pca = PCA(n_components = 6)

# %% [markdown]
# ## Make Pipeline

# %% [markdown]
# **By using mean imputation, null values can be imputed**

# %% [markdown]
# **Data has to be standardized to address the scale difference**

# %%
num_pipeline = make_pipeline(SimpleImputer(strategy = 'mean'), StandardScaler(), pca)

# %%
# Pass the raw data through pipeline

processed = num_pipeline.fit(df1[numeric_features])

# %%
processed
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler()),
#                 ('pca', PCA(n_components=6))])

# %%
# Apply the pipeline on the dataset
univ = pd.DataFrame(processed.transform(df1[numeric_features]))

univ
# Out:
#            0         1         2         3         4         5
# 0  -1.008824 -1.069154  0.078815  0.053320 -0.124905 -0.045254
# 1  -2.822327  2.252320  0.844907  0.136340 -0.091849 -0.173769
# 2   1.112562  1.626748 -0.256960  1.080296 -0.175069  0.334079
# 3  -0.683955  0.031322  0.150691 -0.081396 -0.627660  0.091600
# 4  -0.310925 -0.640049  0.006737  0.165489  0.018108 -0.023414
# 5  -1.695867 -0.348666 -0.255731  0.009171 -0.055605 -0.035697
# 6  -1.245805 -0.496317 -0.043130 -0.218671  0.290790 -0.074597
# 7  -0.389018 -0.782644 -0.464465  0.064073 -0.549292 -0.083806
# 8  -2.373384 -0.392515  0.112782 -0.452592 -0.243764  0.259592
# 9  -1.402687  2.116496 -0.446030 -0.641238  0.218553 -0.224627
# 10 -1.725638  0.081015  0.162213  0.250658  0.239282  0.241233
# 11 -0.449924 -0.014987 -0.180488  0.223463  0.275237 -0.314374
# 12  0.041397 -1.013733 -0.510428  0.215909  0.441974  0.004041
# 13  3.235439 -0.374376 -0.485634 -0.507470 -0.658788 -0.111189
# 14 -2.235687 -0.375465 -0.392037  0.413228 -0.415173  0.028415
# 15  5.174525  0.778296 -0.389433 -0.236373  0.169297 -0.026913
# 16 -1.698826 -0.311548  0.316043 -0.300174 -0.164922  0.109865
# 17  4.579734 -0.354187  1.498583 -0.459825 -0.171403  0.110930
# 18  0.823490 -0.707026  1.425236  0.741766  0.240129 -0.245479
# 19 -0.125520  0.675722  0.041166 -0.477414  0.469623  0.222028
# 20  1.964419 -0.230463 -0.277851 -0.069454  0.812682  0.168372
# 21 -0.541420 -0.083561 -0.308284  0.126713  0.052153 -0.042461
# 22  0.533489 -1.021195 -0.435299  0.157596  0.353761 -0.068257
# 23  3.549813  0.777644 -0.438257  0.331383 -0.354553 -0.092261
# 24 -2.305058 -0.123680  0.246856 -0.524799  0.051394 -0.008058

# %% [markdown]
# ## Save the End to End PCA pipeline with Imputation and Standardization

# %%
import joblib

joblib.dump(processed, 'Data_prep_DimRed')
# Out:
# ['Data_prep_DimRed']

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Swapnil Mishra\\Desktop\\DS_Codes_Swapnil\\PCA\\pca_flask\\pca'

# %% [markdown]
# ## Import the pipeline

# %%
model = joblib.load("Data_prep_DimRed")

# %%
model
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler()),
#                 ('pca', PCA(n_components=6))])

# %% [markdown]
# ## Apply the saved model on to the Dataset to extract PCA values

# %%
pca_res = pd.DataFrame(model.transform(df1[numeric_features]))

pca_res
# Out:
#            0         1         2         3         4         5
# 0  -1.008824 -1.069154  0.078815  0.053320 -0.124905 -0.045254
# 1  -2.822327  2.252320  0.844907  0.136340 -0.091849 -0.173769
# 2   1.112562  1.626748 -0.256960  1.080296 -0.175069  0.334079
# 3  -0.683955  0.031322  0.150691 -0.081396 -0.627660  0.091600
# 4  -0.310925 -0.640049  0.006737  0.165489  0.018108 -0.023414
# 5  -1.695867 -0.348666 -0.255731  0.009171 -0.055605 -0.035697
# 6  -1.245805 -0.496317 -0.043130 -0.218671  0.290790 -0.074597
# 7  -0.389018 -0.782644 -0.464465  0.064073 -0.549292 -0.083806
# 8  -2.373384 -0.392515  0.112782 -0.452592 -0.243764  0.259592
# 9  -1.402687  2.116496 -0.446030 -0.641238  0.218553 -0.224627
# 10 -1.725638  0.081015  0.162213  0.250658  0.239282  0.241233
# 11 -0.449924 -0.014987 -0.180488  0.223463  0.275237 -0.314374
# 12  0.041397 -1.013733 -0.510428  0.215909  0.441974  0.004041
# 13  3.235439 -0.374376 -0.485634 -0.507470 -0.658788 -0.111189
# 14 -2.235687 -0.375465 -0.392037  0.413228 -0.415173  0.028415
# 15  5.174525  0.778296 -0.389433 -0.236373  0.169297 -0.026913
# 16 -1.698826 -0.311548  0.316043 -0.300174 -0.164922  0.109865
# 17  4.579734 -0.354187  1.498583 -0.459825 -0.171403  0.110930
# 18  0.823490 -0.707026  1.425236  0.741766  0.240129 -0.245479
# 19 -0.125520  0.675722  0.041166 -0.477414  0.469623  0.222028
# 20  1.964419 -0.230463 -0.277851 -0.069454  0.812682  0.168372
# 21 -0.541420 -0.083561 -0.308284  0.126713  0.052153 -0.042461
# 22  0.533489 -1.021195 -0.435299  0.157596  0.353761 -0.068257
# 23  3.549813  0.777644 -0.438257  0.331383 -0.354553 -0.092261
# 24 -2.305058 -0.123680  0.246856 -0.524799  0.051394 -0.008058

# %%
# PCA weights

model['pca'].components_
# Out:
# array([[-0.45813885, -0.42716104,  0.42420075,  0.3908408 , -0.36243393,
#         -0.37892093],
#        [ 0.03576417, -0.20143553,  0.31869533, -0.4346534 ,  0.63461057,
#         -0.51470747],
#        [ 0.18078706,  0.49125198, -0.17425864,  0.59925723,  0.20292589,
#         -0.54344578],
#        [ 0.1359349 ,  0.35737683,  0.04516736, -0.51115551, -0.62714633,
#         -0.44403936],
#        [ 0.00545604,  0.51133027,  0.7935202 ,  0.07218408,  0.06811593,
#          0.31462193],
#        [ 0.85885837, -0.38269024,  0.23750061,  0.18088716, -0.16364553,
#          0.00198112]])

# %%
# Take a closer look at the components
components = pd.DataFrame(model['pca'].components_, columns = numeric_features).T
components.columns = ['pc0', 'pc1', 'pc2', 'pc3', 'pc4', 'pc5']

components
# Out:
#                pc0       pc1       pc2       pc3       pc4       pc5
# SAT      -0.458139  0.035764  0.180787  0.135935  0.005456  0.858858
# Top10    -0.427161 -0.201436  0.491252  0.357377  0.511330 -0.382690
# Accept    0.424201  0.318695 -0.174259  0.045167  0.793520  0.237501
# SFRatio   0.390841 -0.434653  0.599257 -0.511156  0.072184  0.180887
# Expenses -0.362434  0.634611  0.202926 -0.627146  0.068116 -0.163646
# GradRate -0.378921 -0.514707 -0.543446 -0.444039  0.314622  0.001981

# %%
print(model['pca'].explained_variance_ratio_)
# Out:
# [0.76862924 0.13140213 0.04771658 0.02696455 0.02106913 0.00421836]

# %%
var1 = np.cumsum(model['pca'].explained_variance_ratio_)

print(var1)
# Out:
# [0.76862924 0.90003138 0.94774795 0.97471251 0.99578164 1.        ]

# %%
# Variance plot for PCA components obtained 
plt.plot(var1, color = "red")

# %% [markdown]
# ## KneeLocator
# Refer the link to understand the parameters used: https://kneed.readthedocs.io/en/stable/parameters.html

# %%
# from kneed import KneeLocator
kl = KneeLocator(range(len(var1)), var1, curve = 'concave', direction = "increasing") 
# The line is pretty linear hence Kneelocator is not able to detect the knee/elbow appropriately
kl.elbow
plt.style.use("seaborn")
plt.plot(range(len(var1)), var1)
plt.xticks(range(len(var1)))
plt.ylabel("Interia")
plt.axvline(x = kl.elbow, color = 'r', label = 'axvline - full height', ls = '--')
plt.show()

# %% [markdown]
# Kneelocator recommends 3 PCs as the ideal number of features to be considered

# %% [markdown]
# # PCA for Feature Extraction

# %%
# Final dataset with manageable number of columns (Feature Extraction)

final = pd.concat([df.Univ, pca_res.iloc[:, 0:3]], axis = 1)
final.columns = ['Univ', 'pc0', 'pc1', 'pc2']
final
# Out:
#             Univ       pc0       pc1       pc2
# 0          Brown -1.008824 -1.069154  0.078815
# 1        CalTech -2.822327  2.252320  0.844907
# 2            CMU  1.112562  1.626748 -0.256960
# 3       Columbia -0.683955  0.031322  0.150691
# 4        Cornell -0.310925 -0.640049  0.006737
# 5      Dartmouth -1.695867 -0.348666 -0.255731
# 6           Duke -1.245805 -0.496317 -0.043130
# 7     Georgetown -0.389018 -0.782644 -0.464465
# 8        Harvard -2.373384 -0.392515  0.112782
# 9   JohnsHopkins -1.402687  2.116496 -0.446030
# 10           MIT -1.725638  0.081015  0.162213
# 11  Northwestern -0.449924 -0.014987 -0.180488
# 12     NotreDame  0.041397 -1.013733 -0.510428
# 13     PennState  3.235439 -0.374376 -0.485634
# 14     Princeton -2.235687 -0.375465 -0.392037
# 15        Purdue  5.174525  0.778296 -0.389433
# 16      Stanford -1.698826 -0.311548  0.316043
# 17      TexasA&M  4.579734 -0.354187  1.498583
# 18    UCBerkeley  0.823490 -0.707026  1.425236
# 19      UChicago -0.125520  0.675722  0.041166
# 20     UMichigan  1.964419 -0.230463 -0.277851
# 21         UPenn -0.541420 -0.083561 -0.308284
# 22           UVA  0.533489 -1.021195 -0.435299
# 23    UWisconsin  3.549813  0.777644 -0.438257
# 24          Yale -2.305058 -0.123680  0.246856

# %%
# Scatter diagram
ax = final.plot(x = 'pc0', y = 'pc1', kind = 'scatter', figsize = (12, 8))
final[['pc0', 'pc1', 'Univ']].apply(lambda x: ax.text(*x), axis = 1)
# Out:
# 0     Text(-1.0088236818639644, -1.0691538769881213,...
# 1     Text(-2.822326558999184, 2.252320203822683, 'C...
# 2     Text(1.1125616303660952, 1.6267483806870129, '...
# 3     Text(-0.6839552605503287, 0.03132174701492002,...
# 4     Text(-0.31092450417586887, -0.6400486030934261...
# 5     Text(-1.6958668099846925, -0.34866586849687603...
# 6     Text(-1.2458054535709076, -0.4963168815923306,...
# 7     Text(-0.3890182750152041, -0.782643617703161, ...
# 8     Text(-2.373384294420653, -0.3925147946430451, ...
# 9     Text(-1.402687491430432, 2.1164964889463245, '...
# 10    Text(-1.7256378326780726, 0.08101450295852636,...
# 11    Text(-0.4499242233205679, -0.01498705112450598...
# 12    Text(0.041396598813714644, -1.013733035387051,...
# 13    Text(3.235438940384006, -0.3743761890622639, '...
# 14    Text(-2.235686952227566, -0.3754649920546697, ...
# 15    Text(5.174524534636291, 0.7782961511779145, 'P...
# 16    Text(-1.6988262921827855, -0.3115475777109657,...
# 17    Text(4.579733553315189, -0.35418661823248293, ...
# 18    Text(0.8234901694916059, -0.7070257866977379, ...
# 19    Text(-0.12552040956364757, 0.675721574707438, ...
# 20    Text(1.9644187990346667, -0.2304631446875575, ...
# 21    Text(-0.54141986882094, -0.08356122797533051, ...
# 22    Text(0.5334887220377832, -1.0211945283051824, ...
# 23    Text(3.5498134533126633, 0.7776444344040756, '...
# 24    Text(-2.3050584925872, -0.12367968996418713, '...
# dtype: object

# %% [markdown]
# # Prediction on new data

# %%
newdf = pd.read_excel(r"C:\Users\Swapnil Mishra\Desktop\DS_Codes_Swapnil\PCA\University_Clustering\new_Univ_4_pred.xlsx")

newdf
# Out:
#    UnivID                       Univ State     SAT  Top10  Accept  SFRatio  \
# 0      26                UWashington    NY  1280.0   83.0    33.0     13.0
# 1      27                UCalifornia    CA  1340.0   89.0    23.0     10.0
# 2      28              Santa Barbara    NC  1315.0   90.0    30.0      NaN
# 3      29                  UMaryland    DC     NaN   74.0    24.0     12.0
# 4      30            Rice University    MA  1400.0   91.0     NaN     11.0
# 5      31                     UMiami    MD  1305.0   75.0    44.0      7.0
# 6      32                  UVirginia    MA  1380.0    NaN    30.0     10.0
# 7      33  Indiana University Kokomo    IL  1260.0   85.0    39.0     11.0
# 8      34      University at Buffalo    IN  1255.0   81.0    42.0     13.0
#
#    Expenses  GradRate
# 0   21864.0      90.0
# 1   32162.0      95.0
# 2   31585.0      95.0
# 3   20126.0      92.0
# 4   39525.0       NaN
# 5   58691.0      87.0
# 6   34870.0      91.0
# 7       NaN      89.0
# 8   15122.0      94.0

# %%
# Drop the unwanted features
newdf1 = newdf.drop(["UnivID"], axis = 1)

# %%
num_feat = newdf1.select_dtypes(exclude = ['object']).columns

# %%
new_res = pd.DataFrame(model.transform(newdf1[numeric_features]))

new_res
# Out:
#           0         1         2         3         4         5
# 0 -0.310925 -0.640049  0.006737  0.165489  0.018108 -0.023414
# 1 -1.695867 -0.348666 -0.255731  0.009171 -0.055605 -0.035697
# 2 -1.176329 -0.573581  0.063394 -0.309534  0.303622 -0.042442
# 3 -0.389018 -0.782644 -0.464465  0.064073 -0.549292 -0.083806
# 4 -1.378941  0.622546  0.518625  0.123536  0.424306  0.566928
# 5 -1.402687  2.116496 -0.446030 -0.641238  0.218553 -0.224627
# 6 -1.332604  0.266357 -0.289792 -0.078167 -0.231197  0.593349
# 7 -0.432897 -0.044802 -0.190022  0.252927  0.272037 -0.306686
# 8  0.041397 -1.013733 -0.510428  0.215909  0.441974  0.004041
